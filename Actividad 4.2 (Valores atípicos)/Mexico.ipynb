# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Mexico_sin_valoresNulos.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26582 entries, 0 to 26581
# Data columns (total 52 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   26582 non-null  int64
#  1   id                           26582 non-null  int64
#  2   scrape_id                    26582 non-null  int64
#  3   last_scraped                 26582 non-null  object
#  4   source                       26582 non-null  object
#  5   name                         26582 non-null  object
#  6   description                  26582 non-null  object
#  7   host_id                      26582 non-null  int64
#  8   host_name                    26582 non-null  object
#  9   host_since                   26582 non-null  object
#  10  host_location                26582 non-null  object
#  11  host_response_time           26582 non-null  object
#  12  host_response_rate           26582 non-null  object
#  13  host_acceptance_rate         26582 non-null  object
#  14  host_is_superhost            26582 non-null  object
#  15  host_listings_count          26582 non-null  int64
#  16  host_total_listings_count    26582 non-null  int64
#  17  host_verifications           26582 non-null  object
#  18  host_identity_verified       26582 non-null  object
#  19  neighbourhood_cleansed       26582 non-null  object
#  20  latitude                     26582 non-null  float64
#  21  longitude                    26582 non-null  float64
#  22  property_type                26582 non-null  object
#  23  room_type                    26582 non-null  object
#  24  accommodates                 26582 non-null  int64
#  25  bathrooms                    26582 non-null  float64
#  26  bedrooms                     26582 non-null  float64
#  27  beds                         26582 non-null  float64
#  28  amenities                    26582 non-null  object
#  29  price                        26582 non-null  object
#  30  minimum_nights               26582 non-null  int64
#  31  maximum_nights               26582 non-null  int64
#  32  has_availability             26582 non-null  object
#  33  availability_30              26582 non-null  int64
#  34  availability_60              26582 non-null  int64
#  35  availability_90              26582 non-null  int64
#  36  availability_365             26582 non-null  int64
#  37  number_of_reviews            26582 non-null  int64
#  38  number_of_reviews_ltm        26582 non-null  int64
#  39  number_of_reviews_l30d       26582 non-null  int64
#  40  first_review                 26582 non-null  object
#  41  last_review                  26582 non-null  object
#  42  review_scores_rating         26582 non-null  float64
#  43  review_scores_accuracy       26582 non-null  float64
#  44  review_scores_cleanliness    26582 non-null  float64
#  45  review_scores_checkin        26582 non-null  float64
#  46  review_scores_communication  26582 non-null  float64
#  47  review_scores_location       26582 non-null  float64
#  48  review_scores_value          26582 non-null  float64
#  49  license                      26582 non-null  float64
#  50  instant_bookable             26582 non-null  object
#  51  reviews_per_month            26582 non-null  float64
# dtypes: float64(14), int64(16), object(22)
# memory usage: 10.5+ MB

# %%
cuantitativas = data.select_dtypes(include=['float64'])
cualitativas = data.select_dtypes(include=['object', 'datetime','int64'])

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas.plot(kind='box', vert= False)
plt.title("Valores atipicos del Dataframe")
plt.show() #dibuja el driagrama de caja / bigote de cada columna del dataframe

# %%
cuantitativas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26582 entries, 0 to 26581
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   latitude                     26582 non-null  float64
#  1   longitude                    26582 non-null  float64
#  2   bathrooms                    26582 non-null  float64
#  3   bedrooms                     26582 non-null  float64
#  4   beds                         26582 non-null  float64
#  5   review_scores_rating         26582 non-null  float64
#  6   review_scores_accuracy       26582 non-null  float64
#  7   review_scores_cleanliness    26582 non-null  float64
#  8   review_scores_checkin        26582 non-null  float64
#  9   review_scores_communication  26582 non-null  float64
#  10  review_scores_location       26582 non-null  float64
#  11  review_scores_value          26582 non-null  float64
#  12  license                      26582 non-null  float64
#  13  reviews_per_month            26582 non-null  float64
# dtypes: float64(14)
# memory usage: 2.8 MB

# %% [markdown]
# Desviación estándar

# %%
y = cuantitativas
Limite_Superior = y.mean() + 3*y.std()
Limite_Inferior = y.mean() - 3*y.std()

print("Limite superior permitido ", Limite_Superior)
print("Limite inferior permitido ", Limite_Inferior)
# Out:
# Limite superior permitido  latitude                       19.532892
# longitude                     -99.066742
# bathrooms                       4.735292
# bedrooms                        5.386100
# beds                            7.095158
# review_scores_rating            5.790227
# review_scores_accuracy          5.771173
# review_scores_cleanliness       5.874593
# review_scores_checkin           5.706628
# review_scores_communication     5.807539
# review_scores_location          5.650290
# review_scores_value             5.772903
# license                         0.000000
# reviews_per_month               7.574365
# dtype: float64
# Limite inferior permitido  latitude                       19.276851
# longitude                     -99.266495
# bathrooms                      -2.109041
# bedrooms                       -2.349082
# beds                           -3.596700
# review_scores_rating            3.735803
# review_scores_accuracy          3.818267
# review_scores_cleanliness       3.648813
# review_scores_checkin           3.968180
# review_scores_communication     3.843969
# review_scores_location          4.029021
# review_scores_value             3.670681
# license                         0.000000
# reviews_per_month              -4.061600
# dtype: float64

# %%
data2 = cuantitativas[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data2
# Out:
#         latitude  longitude  bathrooms  bedrooms  beds  review_scores_rating  \
# 0      19.383820        NaN        1.0       1.0   1.0                  4.80
# 1      19.411620 -99.177940        0.0       5.0   0.0                  4.58
# 2      19.411520 -99.168570        1.0       2.0   2.0                  4.90
# 3      19.356140 -99.163080        1.0       1.0   1.0                  4.91
# 4      19.432110 -99.193270        1.5       1.0   1.0                  4.91
# ...          ...        ...        ...       ...   ...                   ...
# 26577  19.387329 -99.246731        1.0       2.0   2.0                  4.80
# 26578  19.432687 -99.197736        1.0       1.0   1.0                  4.80
# 26579  19.432687 -99.197736        1.0       1.0   1.0                  4.80
# 26580  19.432687 -99.197736        1.0       1.0   1.0                  4.80
# 26581  19.443476 -99.201748        1.0       1.0   1.0                  4.80
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 0                        4.80                       4.70
# 1                        4.56                       4.70
# 2                        4.81                       4.75
# 3                        4.90                       4.96
# 4                        5.00                       5.00
# ...                       ...                        ...
# 26577                    4.80                       5.00
# 26578                    4.80                       5.00
# 26579                    4.80                       5.00
# 26580                    4.80                       5.00
# 26581                    4.80                       5.00
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.80                         4.80
# 1                       4.87                         4.78
# 2                       4.94                         4.92
# 3                       4.96                         4.98
# 4                       5.00                         4.73
# ...                      ...                          ...
# 26577                   4.80                         4.80
# 26578                   4.80                         4.80
# 26579                   4.80                         4.80
# 26580                   4.80                         4.80
# 26581                   4.80                         4.80
#
#        review_scores_location  review_scores_value  license  reviews_per_month
# 0                        4.80                 4.70      0.0               0.41
# 1                        4.98                 4.48      0.0               0.41
# 2                        4.98                 4.91      0.0               0.31
# 3                        4.96                 4.92      0.0               0.83
# 4                        4.91                 4.82      0.0               0.11
# ...                       ...                  ...      ...                ...
# 26577                    4.80                 4.70      0.0               1.00
# 26578                    4.80                 4.70      0.0               1.00
# 26579                    4.80                 4.70      0.0               1.00
# 26580                    4.80                 4.70      0.0               1.00
# 26581                    4.80                 4.70      0.0               1.00
#
# [26582 rows x 14 columns]

# %%
valores_nulos = data2.isnull().sum()
valores_nulos
# Out:
# latitude                       357
# longitude                      712
# bathrooms                      309
# bedrooms                       286
# beds                           334
# review_scores_rating           408
# review_scores_accuracy         402
# review_scores_cleanliness      430
# review_scores_checkin          310
# review_scores_communication    435
# review_scores_location         518
# review_scores_value            467
# license                          0
# reviews_per_month              398
# dtype: int64

# %%
data_clean = data2.copy()
data_clean = data_clean.fillna(round(data2.mean(),1))
data_clean
# Out:
#         latitude  longitude  bathrooms  bedrooms  beds  review_scores_rating  \
# 0      19.383820 -99.200000        1.0       1.0   1.0                  4.80
# 1      19.411620 -99.177940        0.0       5.0   0.0                  4.58
# 2      19.411520 -99.168570        1.0       2.0   2.0                  4.90
# 3      19.356140 -99.163080        1.0       1.0   1.0                  4.91
# 4      19.432110 -99.193270        1.5       1.0   1.0                  4.91
# ...          ...        ...        ...       ...   ...                   ...
# 26577  19.387329 -99.246731        1.0       2.0   2.0                  4.80
# 26578  19.432687 -99.197736        1.0       1.0   1.0                  4.80
# 26579  19.432687 -99.197736        1.0       1.0   1.0                  4.80
# 26580  19.432687 -99.197736        1.0       1.0   1.0                  4.80
# 26581  19.443476 -99.201748        1.0       1.0   1.0                  4.80
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 0                        4.80                       4.70
# 1                        4.56                       4.70
# 2                        4.81                       4.75
# 3                        4.90                       4.96
# 4                        5.00                       5.00
# ...                       ...                        ...
# 26577                    4.80                       5.00
# 26578                    4.80                       5.00
# 26579                    4.80                       5.00
# 26580                    4.80                       5.00
# 26581                    4.80                       5.00
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.80                         4.80
# 1                       4.87                         4.78
# 2                       4.94                         4.92
# 3                       4.96                         4.98
# 4                       5.00                         4.73
# ...                      ...                          ...
# 26577                   4.80                         4.80
# 26578                   4.80                         4.80
# 26579                   4.80                         4.80
# 26580                   4.80                         4.80
# 26581                   4.80                         4.80
#
#        review_scores_location  review_scores_value  license  reviews_per_month
# 0                        4.80                 4.70      0.0               0.41
# 1                        4.98                 4.48      0.0               0.41
# 2                        4.98                 4.91      0.0               0.31
# 3                        4.96                 4.92      0.0               0.83
# 4                        4.91                 4.82      0.0               0.11
# ...                       ...                  ...      ...                ...
# 26577                    4.80                 4.70      0.0               1.00
# 26578                    4.80                 4.70      0.0               1.00
# 26579                    4.80                 4.70      0.0               1.00
# 26580                    4.80                 4.70      0.0               1.00
# 26581                    4.80                 4.70      0.0               1.00
#
# [26582 rows x 14 columns]

# %%
valores_nulos = data_clean.isnull().sum()
valores_nulos
# Out:
# latitude                       0
# longitude                      0
# bathrooms                      0
# bedrooms                       0
# beds                           0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# license                        0
# reviews_per_month              0
# dtype: int64

# %% [markdown]
# Procedimiento: Cuartiles

# %%
y = cuantitativas
percentile25=y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr=percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr
print("Limite Superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite Superior permitido latitude                       19.494089
# longitude                     -99.117734
# bathrooms                       3.500000
# bedrooms                        3.500000
# beds                            3.500000
# review_scores_rating            5.255000
# review_scores_accuracy          5.230000
# review_scores_cleanliness       5.400000
# review_scores_checkin           5.300000
# review_scores_communication     5.300000
# review_scores_location          5.300000
# review_scores_value             5.215000
# license                         0.000000
# reviews_per_month               5.540000
# dtype: float64
# Limite inferior permitido latitude                       19.327982
# longitude                     -99.215777
# bathrooms                      -0.500000
# bedrooms                       -0.500000
# beds                           -0.500000
# review_scores_rating            4.415000
# review_scores_accuracy          4.510000
# review_scores_cleanliness       4.280000
# review_scores_checkin           4.500000
# review_scores_communication     4.500000
# review_scores_location          4.500000
# review_scores_value             4.375000
# license                         0.000000
# reviews_per_month              -2.620000
# dtype: float64

# %%
data2_iqr = cuantitativas[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data2_iqr
# Out:
#         latitude  longitude  bathrooms  bedrooms  beds  review_scores_rating  \
# 0      19.383820        NaN        1.0       1.0   1.0                  4.80
# 1      19.411620 -99.177940        0.0       NaN   0.0                  4.58
# 2      19.411520 -99.168570        1.0       2.0   2.0                  4.90
# 3      19.356140 -99.163080        1.0       1.0   1.0                  4.91
# 4      19.432110 -99.193270        1.5       1.0   1.0                  4.91
# ...          ...        ...        ...       ...   ...                   ...
# 26577  19.387329        NaN        1.0       2.0   2.0                  4.80
# 26578  19.432687 -99.197736        1.0       1.0   1.0                  4.80
# 26579  19.432687 -99.197736        1.0       1.0   1.0                  4.80
# 26580  19.432687 -99.197736        1.0       1.0   1.0                  4.80
# 26581  19.443476 -99.201748        1.0       1.0   1.0                  4.80
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 0                        4.80                       4.70
# 1                        4.56                       4.70
# 2                        4.81                       4.75
# 3                        4.90                       4.96
# 4                        5.00                       5.00
# ...                       ...                        ...
# 26577                    4.80                       5.00
# 26578                    4.80                       5.00
# 26579                    4.80                       5.00
# 26580                    4.80                       5.00
# 26581                    4.80                       5.00
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.80                         4.80
# 1                       4.87                         4.78
# 2                       4.94                         4.92
# 3                       4.96                         4.98
# 4                       5.00                         4.73
# ...                      ...                          ...
# 26577                   4.80                         4.80
# 26578                   4.80                         4.80
# 26579                   4.80                         4.80
# 26580                   4.80                         4.80
# 26581                   4.80                         4.80
#
#        review_scores_location  review_scores_value  license  reviews_per_month
# 0                        4.80                 4.70      0.0               0.41
# 1                        4.98                 4.48      0.0               0.41
# 2                        4.98                 4.91      0.0               0.31
# 3                        4.96                 4.92      0.0               0.83
# 4                        4.91                 4.82      0.0               0.11
# ...                       ...                  ...      ...                ...
# 26577                    4.80                 4.70      0.0               1.00
# 26578                    4.80                 4.70      0.0               1.00
# 26579                    4.80                 4.70      0.0               1.00
# 26580                    4.80                 4.70      0.0               1.00
# 26581                    4.80                 4.70      0.0               1.00
#
# [26582 rows x 14 columns]

# %%
valores_nulos = data2_iqr.isnull().sum()
valores_nulos
# Out:
# latitude                       1779
# longitude                      2845
# bathrooms                       644
# bedrooms                        858
# beds                           2447
# review_scores_rating           1868
# review_scores_accuracy         2198
# review_scores_cleanliness      1617
# review_scores_checkin          1184
# review_scores_communication    1458
# review_scores_location         1216
# review_scores_value            1944
# license                           0
# reviews_per_month              1008
# dtype: int64

# %%
data3_iqr=data2_iqr.copy()
data3_iqr = data3_iqr.fillna(round(data2_iqr.mean(),1))
data3_iqr
# Out:
#         latitude  longitude  bathrooms  bedrooms  beds  review_scores_rating  \
# 0      19.383820 -99.200000        1.0       1.0   1.0                  4.80
# 1      19.411620 -99.177940        0.0       1.4   0.0                  4.58
# 2      19.411520 -99.168570        1.0       2.0   2.0                  4.90
# 3      19.356140 -99.163080        1.0       1.0   1.0                  4.91
# 4      19.432110 -99.193270        1.5       1.0   1.0                  4.91
# ...          ...        ...        ...       ...   ...                   ...
# 26577  19.387329 -99.200000        1.0       2.0   2.0                  4.80
# 26578  19.432687 -99.197736        1.0       1.0   1.0                  4.80
# 26579  19.432687 -99.197736        1.0       1.0   1.0                  4.80
# 26580  19.432687 -99.197736        1.0       1.0   1.0                  4.80
# 26581  19.443476 -99.201748        1.0       1.0   1.0                  4.80
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 0                        4.80                       4.70
# 1                        4.56                       4.70
# 2                        4.81                       4.75
# 3                        4.90                       4.96
# 4                        5.00                       5.00
# ...                       ...                        ...
# 26577                    4.80                       5.00
# 26578                    4.80                       5.00
# 26579                    4.80                       5.00
# 26580                    4.80                       5.00
# 26581                    4.80                       5.00
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.80                         4.80
# 1                       4.87                         4.78
# 2                       4.94                         4.92
# 3                       4.96                         4.98
# 4                       5.00                         4.73
# ...                      ...                          ...
# 26577                   4.80                         4.80
# 26578                   4.80                         4.80
# 26579                   4.80                         4.80
# 26580                   4.80                         4.80
# 26581                   4.80                         4.80
#
#        review_scores_location  review_scores_value  license  reviews_per_month
# 0                        4.80                 4.70      0.0               0.41
# 1                        4.98                 4.48      0.0               0.41
# 2                        4.98                 4.91      0.0               0.31
# 3                        4.96                 4.92      0.0               0.83
# 4                        4.91                 4.82      0.0               0.11
# ...                       ...                  ...      ...                ...
# 26577                    4.80                 4.70      0.0               1.00
# 26578                    4.80                 4.70      0.0               1.00
# 26579                    4.80                 4.70      0.0               1.00
# 26580                    4.80                 4.70      0.0               1.00
# 26581                    4.80                 4.70      0.0               1.00
#
# [26582 rows x 14 columns]

# %%
Datos_limpios = pd.concat([cualitativas,data3_iqr],axis=1)
Datos_limpios
# Out:
#        Unnamed: 0                   id       scrape_id last_scraped  \
# 0               0                35797  20240925021012   2024-09-25
# 1               1                44616  20240925021012   2024-09-26
# 2               2                67703  20240925021012   2024-09-26
# 3               3                70644  20240925021012   2024-09-25
# 4               4               107078  20240925021012   2024-09-25
# ...           ...                  ...             ...          ...
# 26577       26577  1252141718111439700  20240925021012   2024-09-25
# 26578       26578  1252159821531694005  20240925021012   2024-09-25
# 26579       26579  1252185591721328995  20240925021012   2024-09-25
# 26580       26580  1252218347521498445  20240925021012   2024-09-25
# 26581       26581  1252229157495978163  20240925021012   2024-09-25
#
#                 source                                              name  \
# 0          city scrape                                       Villa Dante
# 1      previous scrape                                      Condesa Haus
# 2          city scrape                 2 bedroom apt. deco bldg, Condesa
# 3          city scrape  Beautiful light Studio Coyoacan- full equipped !
# 4          city scrape                                NEW  DESIGNER LOFT
# ...                ...                                               ...
# 26577      city scrape    Charming 2-Bedroom Retreat in Lomas de Bezares
# 26578      city scrape                     Suite King | District Polanco
# 26579      city scrape                     Suite King | District Polanco
# 26580      city scrape                    Suite Queen | District Polanco
# 26581      city scrape                  Pretty, well centered, amenities
#
#                                              description    host_id  \
# 0      Dentro de Villa un estudio de arte con futon, ...     153786
# 1      A new concept of hosting in mexico through a b...     196253
# 2      Comfortably furnished, sunny, 2 bedroom apt., ...     334451
# 3      COYOACAN designer studio quiet & safe! well eq...     212109
# 4      Is the best ever place triple L <br />Location...     540705
# ...                                                  ...        ...
# 26577  Experience Mexico City in this delightful retr...   67472234
# 26578  This spacious room features a plush king-size ...  596009321
# 26579  Discover the essence of luxury in our king-siz...  596009321
# 26580  Welcome to your refuge in the heart of Polanco...  596009321
# 26581  Known as New Polanco, the Granada colony has p...    6522855
#
#         host_name  host_since  ... beds review_scores_rating  \
# 0            Dici  2010-06-28  ...  1.0                 4.80
# 1        Fernando  2010-08-09  ...  0.0                 4.58
# 2        Nicholas  2011-01-04  ...  2.0                 4.90
# 3          Trisha  2010-08-24  ...  1.0                 4.91
# 4          Andrea  2011-04-27  ...  1.0                 4.91
# ...           ...         ...  ...  ...                  ...
# 26577     HostPal  2016-04-16  ...  2.0                 4.80
# 26578  Luis Angel  2024-08-13  ...  1.0                 4.80
# 26579  Luis Angel  2024-08-13  ...  1.0                 4.80
# 26580  Luis Angel  2024-08-13  ...  1.0                 4.80
# 26581    Salvador  2013-05-22  ...  1.0                 4.80
#
#       review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                       4.80                      4.70                  4.80
# 1                       4.56                      4.70                  4.87
# 2                       4.81                      4.75                  4.94
# 3                       4.90                      4.96                  4.96
# 4                       5.00                      5.00                  5.00
# ...                      ...                       ...                   ...
# 26577                   4.80                      5.00                  4.80
# 26578                   4.80                      5.00                  4.80
# 26579                   4.80                      5.00                  4.80
# 26580                   4.80                      5.00                  4.80
# 26581                   4.80                      5.00                  4.80
#
#        review_scores_communication  review_scores_location  \
# 0                             4.80                    4.80
# 1                             4.78                    4.98
# 2                             4.92                    4.98
# 3                             4.98                    4.96
# 4                             4.73                    4.91
# ...                            ...                     ...
# 26577                         4.80                    4.80
# 26578                         4.80                    4.80
# 26579                         4.80                    4.80
# 26580                         4.80                    4.80
# 26581                         4.80                    4.80
#
#       review_scores_value license reviews_per_month
# 0                    4.70     0.0              0.41
# 1                    4.48     0.0              0.41
# 2                    4.91     0.0              0.31
# 3                    4.92     0.0              0.83
# 4                    4.82     0.0              0.11
# ...                   ...     ...               ...
# 26577                4.70     0.0              1.00
# 26578                4.70     0.0              1.00
# 26579                4.70     0.0              1.00
# 26580                4.70     0.0              1.00
# 26581                4.70     0.0              1.00
#
# [26582 rows x 52 columns]

# %%
Datos_limpios.to_csv("Mexico_limpios.csv")
